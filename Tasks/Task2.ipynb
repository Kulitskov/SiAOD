# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
def trg():
    max = 0
    a = [int(i) for i in input().split()]
    for i in range(len(a)):
        for j in range(i + 1, len(a) - 1):
            c = [a[i], a[j], a[j + 1]]
            c.sort()
            if c[2] < (c[0] + c[1]):
                if max < c[0] + c[1] + c[2]:
                    max = c[0] + c[1] + c[2]
    return max

trg()
# Out:
# 1 1 1 100 101 102
# 303

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
a = input().split()
ans = ""
for k in range(9,-1,-1):
    mass = []
    for i in a:
        if i[0] == str(k):
            mass.append(i)   
    for i in range(len(mass)):
        for j in range(i + 1, len(mass)):
            ind = 1
            while True:
                if len(mass[i]) > ind and len(mass[j]) > ind:
                    if int(mass[j][ind]) == int(mass[i][ind]):
                        if len(mass[i]) == len(mass[j]):
                            break
                        ind += 1
                        continue
                    if int(mass[j][ind]) > int(mass[i][ind]):
                        mass[i], mass[j] = mass[j], mass[i]
                    break
                elif len(mass[j]) > ind:
                    if int(mass[j][ind]) > k:
                        mass[i], mass[j] = mass[j], mass[i]
                    break
                elif len(mass[i]) > ind:
                    if int(mass[i][ind]) < k:
                        mass[i], mass[j] = mass[j], mass[i]
                    break

    for i in mass:
        ans += i + " "
print(ans)
# Out:
# 1 256 1612 78 854
# 854 78 256 1612 1

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %%
import random
m, n = int(input("Длина: ")), int(input("Ширина: "))
mass = [[random.randint(0, 9) for j in range(n)] for i in range(m)]
mind = min(m, n)
maxd = max(m, n)
for i in range(m):
    print(mass[i])
for k in range(mind):
    for i in range(k + 1):
        for j in range(i + 1, k + 1):
            if mass[m-1-k+j][j] < mass[m-1-k+i][i]:
                mass[m-1-k+i][i], mass[m-1-k+j][j] = mass[m-1-k+j][j], mass[m-1-k+i][i]
            if mass[j][n-1-k+j] < mass[i][n-1-k+i]:
                mass[i][n-1-k+i], mass[j][n-1-k+j] = mass[j][n-1-k+j], mass[i][n-1-k+i]
if m < n:
    k1, k2 = 0, 1
else:
    k1, k2 = 1, 0
for k in range(n-m):
        for i in range(mind):
            for j in range(i + 1, mind):
                if mass[j+k1*k][j+k2*k] < mass[i+k1*k][i+k2*k]:
                    mass[i+k1*k][i+k2*k], mass[j+k1*k][j+k2*k] = mass[j+k1*k][j+k2*k], mass[i+k1*k][i+k2*k]    
print()
for i in range(m):
    print(mass[i])
# Out:
# Длина: 4
# Ширина: 8
# [7, 2, 3, 7, 5, 4, 7, 9]
# [4, 0, 9, 5, 6, 8, 6, 0]
# [9, 8, 7, 1, 4, 6, 2, 7]
# [4, 8, 3, 4, 0, 3, 4, 3]
#
# [0, 0, 3, 4, 2, 4, 0, 9]
# [3, 4, 1, 3, 6, 3, 6, 7]
# [8, 4, 7, 2, 4, 6, 5, 7]
# [4, 9, 8, 7, 9, 5, 7, 8]

# %% [markdown]
# ##
